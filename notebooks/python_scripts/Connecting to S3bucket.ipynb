# %%
# %python
# %fs ls 's3://azures3-bucket/Azure Adventure Works/'

# %%
spark.read.format("csv").option("header", "true").load("s3://azures3-bucket/Azure Adventure Works/HumanResources_Department.csv").display()
